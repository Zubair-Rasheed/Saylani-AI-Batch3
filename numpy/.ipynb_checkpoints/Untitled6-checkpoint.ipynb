# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('book.csv')

# %%
df
# Out:
#        Name Father Name       Date  Marks  Age        Job  Experience Scale  \
# 0    zubair     zeeshan  1/31/2022    323   23         BM           2   MG9
# 1      asif      zubair   2/1/2022    434   43        BSM           4  MG10
# 2      khan      faisal   2/2/2022    533   22     Teller           4  MG11
# 3    faisal      noshad   2/3/2022    532   12  Messanger           3  MG12
# 4    shoaib      haider   2/4/2022    155   34        BSM           6  MG10
# 5    nohsad      danish   2/5/2022    663   33      guard           5  MG12
# 6    haider        faiz   2/6/2022    534   44      guard           3  MG12
# 7  khan ali        faaz   2/7/2022    533   55     Teller           6  MG11
# 8   zeeshan        khan   2/8/2022    223   43         BM           4   MG9
#
#    Salary
# 0  134243
# 1   54353
# 2   27865
# 3   25000
# 4   54788
# 5   19860
# 6   19605
# 7   27474
# 8  103252

# %%
print(df.key())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 print(df.key())
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'key'
