# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('book.csv')

# %%
df
# Out:
#        Name Father Name      Date Marks  Age        Job Experience Scale  \
# 0    zubair     zeeshan       Nan   323   23         BM        Nan   MG9
# 1      asif      zubair  2/1/2022   434   43        BSM          4  MG10
# 2      khan      faisal  2/2/2022   Nan   22     Teller          4  MG11
# 3       Nan      noshad  2/3/2022   532  Nan  Messanger          3  MG12
# 4    shoaib      haider       Nan   155   34        BSM        Nan   Nan
# 5    nohsad      danish  2/5/2022   663   33      guard          5  MG12
# 6    haider        faiz  2/6/2022   534   44      guard          3  MG12
# 7  khan ali         Nan  2/7/2022   Nan   55     Teller          6  MG11
# 8       Nan        khan  2/8/2022   223   43        Nan          4   MG9
#
#    Salary
# 0  134243
# 1     Nan
# 2   27865
# 3   25000
# 4   54788
# 5   19860
# 6   19605
# 7   27474
# 8     Nan

# %%
df.rename(columns={'Job':'Job Title',
                  'Father Name': 'F.Name'}) #title name change
# Out:
#        Name   F.Name      Date Marks  Age  Job Title Experience Scale  Salary
# 0    zubair  zeeshan       Nan   323   23         BM        Nan   MG9  134243
# 1      asif   zubair  2/1/2022   434   43        BSM          4  MG10     Nan
# 2      khan   faisal  2/2/2022   Nan   22     Teller          4  MG11   27865
# 3       Nan   noshad  2/3/2022   532  Nan  Messanger          3  MG12   25000
# 4    shoaib   haider       Nan   155   34        BSM        Nan   Nan   54788
# 5    nohsad   danish  2/5/2022   663   33      guard          5  MG12   19860
# 6    haider     faiz  2/6/2022   534   44      guard          3  MG12   19605
# 7  khan ali      Nan  2/7/2022   Nan   55     Teller          6  MG11   27474
# 8       Nan     khan  2/8/2022   223   43        Nan          4   MG9     Nan

# %%
df = pd.read_csv('book.csv',usecols=(0,2,5,6))

# %%
df
# Out:
#        Name      Date        Job Experience
# 0    zubair       Nan         BM        Nan
# 1      asif  2/1/2022        BSM          4
# 2      khan  2/2/2022     Teller          4
# 3       Nan  2/3/2022  Messanger          3
# 4    shoaib       Nan        BSM        Nan
# 5    nohsad  2/5/2022      guard          5
# 6    haider  2/6/2022      guard          3
# 7  khan ali  2/7/2022     Teller          6
# 8       Nan  2/8/2022        Nan          4

# %%
df = pd.read_csv('book.csv')

# %%
df
# Out:
#        Name Father Name      Date Marks  Age        Job Experience Scale  \
# 0    zubair     zeeshan       Nan   323   23         BM        Nan   MG9
# 1      asif      zubair  2/1/2022   434   43        BSM          4  MG10
# 2      khan      faisal  2/2/2022   Nan   22     Teller          4  MG11
# 3       Nan      noshad  2/3/2022   532  Nan  Messanger          3  MG12
# 4    shoaib      haider       Nan   155   34        BSM        Nan   Nan
# 5    nohsad      danish  2/5/2022   663   33      guard          5  MG12
# 6    haider        faiz  2/6/2022   534   44      guard          3  MG12
# 7  khan ali         Nan  2/7/2022   Nan   55     Teller          6  MG11
# 8       Nan        khan  2/8/2022   223   43        Nan          4   MG9
#
#    Salary
# 0  134243
# 1     Nan
# 2   27865
# 3   25000
# 4   54788
# 5   19860
# 6   19605
# 7   27474
# 8     Nan

# %%
df['Name'].values
# Out:
# array(['zubair', 'asif', 'khan', 'Nan', 'shoaib', 'nohsad', 'haider',
#        'khan ali', 'Nan'], dtype=object)

# %%
df.iloc[5,0] = "Noshad"

# %%
df.head()
# Out:
#      Name Father Name      Date Marks  Age        Job Experience Scale  Salary
# 0  zubair     zeeshan       Nan   323   23         BM        Nan   MG9  134243
# 1    asif      zubair  2/1/2022   434   43        BSM          4  MG10     Nan
# 2    khan      faisal  2/2/2022   Nan   22     Teller          4  MG11   27865
# 3     Nan      noshad  2/3/2022   532  Nan  Messanger          3  MG12   25000
# 4  shoaib      haider       Nan   155   34        BSM        Nan   Nan   54788

# %%
df.tail()
# Out:
#        Name Father Name      Date Marks Age     Job Experience Scale Salary
# 4    shoaib      haider       Nan   155  34     BSM        Nan   Nan  54788
# 5    Noshad      danish  2/5/2022   663  33   guard          5  MG12  19860
# 6    haider        faiz  2/6/2022   534  44   guard          3  MG12  19605
# 7  khan ali         Nan  2/7/2022   Nan  55  Teller          6  MG11  27474
# 8       Nan        khan  2/8/2022   223  43     Nan          4   MG9    Nan

# %%
df
# Out:
#        Name Father Name      Date Marks  Age        Job Experience Scale  \
# 0    zubair     zeeshan       Nan   323   23         BM        Nan   MG9
# 1      asif      zubair  2/1/2022   434   43        BSM          4  MG10
# 2      khan      faisal  2/2/2022   Nan   22     Teller          4  MG11
# 3       Nan      noshad  2/3/2022   532  Nan  Messanger          3  MG12
# 4    shoaib      haider       Nan   155   34        BSM        Nan   Nan
# 5    Noshad      danish  2/5/2022   663   33      guard          5  MG12
# 6    haider        faiz  2/6/2022   534   44      guard          3  MG12
# 7  khan ali         Nan  2/7/2022   Nan   55     Teller          6  MG11
# 8       Nan        khan  2/8/2022   223   43        Nan          4   MG9
#
#    Salary
# 0  134243
# 1     Nan
# 2   27865
# 3   25000
# 4   54788
# 5   19860
# 6   19605
# 7   27474
# 8     Nan

# %%
df["Salary"] = [134243, 1234 , 27865, 25000,  54788,19860,     19605, 27474,2335]

# %%
df.iloc[3,0] = "Khan"
df.iloc[8,0] = "Faisal"
df.iloc[7,1] = "John"
df.iloc[0,2] = "2/4/2022" 
df.iloc[4,2] = "3/6/2022"
df.iloc[2,3] = 456
df.iloc[7,3] = 345
df.iloc[3,4] = 32
df.iloc[8,5] = "BSM"
df.iloc[0,6] = 2
df.iloc[4,6] = 3
df.iloc[4,7] = "MG11"

# %%
df
# Out:
#        Name Father Name      Date Marks Age        Job Experience Scale  \
# 0    zubair     zeeshan  2/4/2022   323  23         BM          2   MG9
# 1      asif      zubair  2/1/2022   434  43        BSM          4  MG10
# 2      khan      faisal  2/2/2022   456  22     Teller          4  MG11
# 3      Khan      noshad  2/3/2022   532  32  Messanger          3  MG12
# 4    shoaib      haider  3/6/2022   155  34        BSM          3  MG11
# 5    Noshad      danish  2/5/2022   663  33      guard          5  MG12
# 6    haider        faiz  2/6/2022   534  44      guard          3  MG12
# 7  khan ali        John  2/7/2022   345  55     Teller          6  MG11
# 8    Faisal        khan  2/8/2022   223  43        BSM          4   MG9
#
#    Salary
# 0  134243
# 1    1234
# 2   27865
# 3   25000
# 4   54788
# 5   19860
# 6   19605
# 7   27474
# 8    2335

# %%
df[(df["Job"] == "BM") & (df["Salary"] >= 103500)]
# Out:
#      Name Father Name      Date Marks Age Job Experience Scale  Salary
# 0  zubair     zeeshan  2/4/2022   323  23  BM          2   MG9  134243

# %%
df[(df["Job"] == "BSM") & (df["Experience"] == 4) | (df["Experience"] == 2)]
# Out:
#      Name Father Name      Date Marks Age Job Experience Scale  Salary
# 0  zubair     zeeshan  2/4/2022   323  23  BM          2   MG9  134243

# %%
df
# Out:
#        Name Father Name      Date Marks Age        Job Experience Scale  \
# 0    zubair     zeeshan  2/4/2022   323  23         BM          2   MG9
# 1      asif      zubair  2/1/2022   434  43        BSM          4  MG10
# 2      khan      faisal  2/2/2022   456  22     Teller          4  MG11
# 3      Khan      noshad  2/3/2022   532  32  Messanger          3  MG12
# 4    shoaib      haider  3/6/2022   155  34        BSM          3  MG11
# 5    Noshad      danish  2/5/2022   663  33      guard          5  MG12
# 6    haider        faiz  2/6/2022   534  44      guard          3  MG12
# 7  khan ali        John  2/7/2022   345  55     Teller          6  MG11
# 8    Faisal        khan  2/8/2022   223  43        BSM          4   MG9
#
#    Salary
# 0  134243
# 1    1234
# 2   27865
# 3   25000
# 4   54788
# 5   19860
# 6   19605
# 7   27474
# 8    2335

# %%
df.sort_values("Salary")
# Out:
#        Name Father Name      Date Marks Age        Job Experience Scale  \
# 1      asif      zubair  2/1/2022   434  43        BSM          4  MG10
# 8    Faisal        khan  2/8/2022   223  43        BSM          4   MG9
# 6    haider        faiz  2/6/2022   534  44      guard          3  MG12
# 5    Noshad      danish  2/5/2022   663  33      guard          5  MG12
# 3      Khan      noshad  2/3/2022   532  32  Messanger          3  MG12
# 7  khan ali        John  2/7/2022   345  55     Teller          6  MG11
# 2      khan      faisal  2/2/2022   456  22     Teller          4  MG11
# 4    shoaib      haider  3/6/2022   155  34        BSM          3  MG11
# 0    zubair     zeeshan  2/4/2022   323  23         BM          2   MG9
#
#    Salary
# 1    1234
# 8    2335
# 6   19605
# 5   19860
# 3   25000
# 7   27474
# 2   27865
# 4   54788
# 0  134243

# %%
df.sort_index()
# Out:
#        Name Father Name      Date Marks Age        Job Experience Scale  \
# 0    zubair     zeeshan  2/4/2022   323  23         BM          2   MG9
# 1      asif      zubair  2/1/2022   434  43        BSM          4  MG10
# 2      khan      faisal  2/2/2022   456  22     Teller          4  MG11
# 3      Khan      noshad  2/3/2022   532  32  Messanger          3  MG12
# 4    shoaib      haider  3/6/2022   155  34        BSM          3  MG11
# 5    Noshad      danish  2/5/2022   663  33      guard          5  MG12
# 6    haider        faiz  2/6/2022   534  44      guard          3  MG12
# 7  khan ali        John  2/7/2022   345  55     Teller          6  MG11
# 8    Faisal        khan  2/8/2022   223  43        BSM          4   MG9
#
#    Salary
# 0  134243
# 1    1234
# 2   27865
# 3   25000
# 4   54788
# 5   19860
# 6   19605
# 7   27474
# 8    2335

# %%
df
# Out:
#        Name Father Name      Date Marks Age        Job Experience Scale  \
# 0    zubair     zeeshan  2/4/2022   323  23         BM          2   MG9
# 1      asif      zubair  2/1/2022   434  43        BSM          4  MG10
# 2      khan      faisal  2/2/2022   456  22     Teller          4  MG11
# 3      Khan      noshad  2/3/2022   532  32  Messanger          3  MG12
# 4    shoaib      haider  3/6/2022   155  34        BSM          3  MG11
# 5    Noshad      danish  2/5/2022   663  33      guard          5  MG12
# 6    haider        faiz  2/6/2022   534  44      guard          3  MG12
# 7  khan ali        John  2/7/2022   345  55     Teller          6  MG11
# 8    Faisal        khan  2/8/2022   223  43        BSM          4   MG9
#
#    Salary
# 0  134243
# 1    1234
# 2   27865
# 3   25000
# 4   54788
# 5   19860
# 6   19605
# 7   27474
# 8    2335

# %%
df.value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [27], in <cell line: 1>()
# ----> 1 df.value_counts["Age"]
#
# TypeError: 'method' object is not subscriptable

# %%
titanic = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
type(titanic)

# %%
tit = titanic.set_index("PassengerId")

# %%
tit

# %%
tit["Age"].values

# %%
tit.keys()

# %%
tit

# %%
tit.rename(columns={"Name":"Name."})

# %%
tit.isna().sum()

# %%
tit.isna().sum() / len(tit) * 100

# %%
len(tit.dropna())
