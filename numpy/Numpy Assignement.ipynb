# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('book.csv')

# %%
df.dtypes
# Out:
# Name           object
# Father Name    object
# Date           object
# Marks          object
# Age            object
# Job            object
# Experience     object
# Scale          object
# Salary         object
# dtype: object

# %%
df.iloc[3,0] = "Khan"
df.iloc[8,0] = "Faisal"
df.iloc[7,1] = "John"
df.iloc[0,2] = "2/4/2022" 
df.iloc[4,2] = "3/6/2022"
df.iloc[2,3] = "456"
df.iloc[7,3] = "345"
df.iloc[3,4] = "32"
df.iloc[8,5] = "BSM"
df.iloc[0,6] = "2"
df.iloc[4,6] = "3"
df.iloc[4,7] = "MG11"
df["Salary"] = [134243, 1234 , 27865, 25000,  54788,19860,     19605, 27474,2335]

# %%
df
# Out:
#        Name Father Name      Date Marks Age        Job Experience Scale  \
# 0    zubair     zeeshan  2/4/2022   323  23         BM          2   MG9
# 1      asif      zubair  2/1/2022   434  43        BSM          4  MG10
# 2      khan      faisal  2/2/2022   456  22     Teller          4  MG11
# 3      Khan      noshad  2/3/2022   532  32  Messanger          3  MG12
# 4    shoaib      haider  3/6/2022   155  34        BSM          3  MG11
# 5    nohsad      danish  2/5/2022   663  33      guard          5  MG12
# 6    haider        faiz  2/6/2022   534  44      guard          3  MG12
# 7  khan ali        John  2/7/2022   345  55     Teller          6  MG11
# 8    Faisal        khan  2/8/2022   223  43        BSM          4   MG9
#
#    Salary
# 0  134243
# 1    1234
# 2   27865
# 3   25000
# 4   54788
# 5   19860
# 6   19605
# 7   27474
# 8    2335

# %%
df
# Out:
#        Name Father Name      Date Marks Age        Job Experience Scale  \
# 0    zubair     zeeshan  2/4/2022   323  23         BM          2   MG9
# 1      asif      zubair  2/1/2022   434  43        BSM          4  MG10
# 2      khan      faisal  2/2/2022   456  22     Teller          4  MG11
# 3      Khan      noshad  2/3/2022   532  32  Messanger          3  MG12
# 4    shoaib      haider  3/6/2022   155  34        BSM          3  MG11
# 5    nohsad      danish  2/5/2022   663  33      guard          5  MG12
# 6    haider        faiz  2/6/2022   534  44      guard          3  MG12
# 7  khan ali        John  2/7/2022   345  55     Teller          6  MG11
# 8    Faisal        khan  2/8/2022   223  43        BSM          4   MG9
#
#    Salary
# 0  134243
# 1    1234
# 2   27865
# 3   25000
# 4   54788
# 5   19860
# 6   19605
# 7   27474
# 8    2335

# %%
df["Age"] = df.Age.astype(int)
df["Marks"] = df.Marks.astype(int)
df["Experience"] = df.Experience.astype(int)

# %%
df["Salary"].sum()
df["Age"].sum()
# Out:
# 329

# %%
df.dtypes
# Out:
# Name           object
# Father Name    object
# Date           object
# Marks           int32
# Age             int32
# Job            object
# Experience      int32
# Scale          object
# Salary          int64
# dtype: object

# %%
df["Age"] = pd.to_numeric(df["Age"])
df["Age"].dtypes
# Out:
# dtype('int32')

# %%
df.rename(columns={'Job':'Job Title',
                  'Father Name': 'F.Name'}) #title name change
# Out:
#        Name   F.Name      Date  Marks  Age  Job Title  Experience Scale  \
# 0    zubair  zeeshan  2/4/2022    323   23         BM           2   MG9
# 1      asif   zubair  2/1/2022    434   43        BSM           4  MG10
# 2      khan   faisal  2/2/2022    456   22     Teller           4  MG11
# 3      Khan   noshad  2/3/2022    532   32  Messanger           3  MG12
# 4    shoaib   haider  3/6/2022    155   34        BSM           3  MG11
# 5    nohsad   danish  2/5/2022    663   33      guard           5  MG12
# 6    haider     faiz  2/6/2022    534   44      guard           3  MG12
# 7  khan ali     John  2/7/2022    345   55     Teller           6  MG11
# 8    Faisal     khan  2/8/2022    223   43        BSM           4   MG9
#
#    Salary
# 0  134243
# 1    1234
# 2   27865
# 3   25000
# 4   54788
# 5   19860
# 6   19605
# 7   27474
# 8    2335

# %%
df.to_csv("book1.csv",index=False)

# %%
df = pd.read_csv('book1.csv')

# %%
df
# Out:
#        Name Father Name      Date  Marks  Age        Job  Experience Scale  \
# 0    zubair     zeeshan  2/4/2022    323   23         BM           2   MG9
# 1      asif      zubair  2/1/2022    434   43        BSM           4  MG10
# 2      khan      faisal  2/2/2022    456   22     Teller           4  MG11
# 3      Khan      noshad  2/3/2022    532   32  Messanger           3  MG12
# 4    shoaib      haider  3/6/2022    155   34        BSM           3  MG11
# 5    nohsad      danish  2/5/2022    663   33      guard           5  MG12
# 6    haider        faiz  2/6/2022    534   44      guard           3  MG12
# 7  khan ali        John  2/7/2022    345   55     Teller           6  MG11
# 8    Faisal        khan  2/8/2022    223   43        BSM           4   MG9
#
#    Salary
# 0  134243
# 1    1234
# 2   27865
# 3   25000
# 4   54788
# 5   19860
# 6   19605
# 7   27474
# 8    2335

# %%
df['Name'].values
# Out:
# array(['zubair', 'asif', 'khan', 'Khan', 'shoaib', 'nohsad', 'haider',
#        'khan ali', 'Faisal'], dtype=object)

# %%
df.iloc[5,0] = "Noshad"

# %%
df.head()
# Out:
#      Name Father Name      Date  Marks  Age        Job  Experience Scale  \
# 0  zubair     zeeshan  2/4/2022    323   23         BM           2   MG9
# 1    asif      zubair  2/1/2022    434   43        BSM           4  MG10
# 2    khan      faisal  2/2/2022    456   22     Teller           4  MG11
# 3    Khan      noshad  2/3/2022    532   32  Messanger           3  MG12
# 4  shoaib      haider  3/6/2022    155   34        BSM           3  MG11
#
#    Salary
# 0  134243
# 1    1234
# 2   27865
# 3   25000
# 4   54788

# %%
df.tail()
# Out:
#        Name Father Name      Date  Marks  Age     Job  Experience Scale  \
# 4    shoaib      haider  3/6/2022    155   34     BSM           3  MG11
# 5    Noshad      danish  2/5/2022    663   33   guard           5  MG12
# 6    haider        faiz  2/6/2022    534   44   guard           3  MG12
# 7  khan ali        John  2/7/2022    345   55  Teller           6  MG11
# 8    Faisal        khan  2/8/2022    223   43     BSM           4   MG9
#
#    Salary
# 4   54788
# 5   19860
# 6   19605
# 7   27474
# 8    2335

# %%
df
# Out:
#        Name Father Name      Date  Marks  Age        Job  Experience Scale  \
# 0    zubair     zeeshan  2/4/2022    323   23         BM           2   MG9
# 1      asif      zubair  2/1/2022    434   43        BSM           4  MG10
# 2      khan      faisal  2/2/2022    456   22     Teller           4  MG11
# 3      Khan      noshad  2/3/2022    532   32  Messanger           3  MG12
# 4    shoaib      haider  3/6/2022    155   34        BSM           3  MG11
# 5    Noshad      danish  2/5/2022    663   33      guard           5  MG12
# 6    haider        faiz  2/6/2022    534   44      guard           3  MG12
# 7  khan ali        John  2/7/2022    345   55     Teller           6  MG11
# 8    Faisal        khan  2/8/2022    223   43        BSM           4   MG9
#
#    Salary
# 0  134243
# 1    1234
# 2   27865
# 3   25000
# 4   54788
# 5   19860
# 6   19605
# 7   27474
# 8    2335

# %%
df
# Out:
#        Name Father Name      Date  Marks  Age        Job  Experience Scale  \
# 0    zubair     zeeshan  2/4/2022    323   23         BM           2   MG9
# 1      asif      zubair  2/1/2022    434   43        BSM           4  MG10
# 2      khan      faisal  2/2/2022    456   22     Teller           4  MG11
# 3      Khan      noshad  2/3/2022    532   32  Messanger           3  MG12
# 4    shoaib      haider  3/6/2022    155   34        BSM           3  MG11
# 5    Noshad      danish  2/5/2022    663   33      guard           5  MG12
# 6    haider        faiz  2/6/2022    534   44      guard           3  MG12
# 7  khan ali        John  2/7/2022    345   55     Teller           6  MG11
# 8    Faisal        khan  2/8/2022    223   43        BSM           4   MG9
#
#    Salary
# 0  134243
# 1    1234
# 2   27865
# 3   25000
# 4   54788
# 5   19860
# 6   19605
# 7   27474
# 8    2335

# %%
df[(df["Job"] == "BM") & (df["Salary"] >= 103500)]
# Out:
#      Name Father Name      Date  Marks  Age Job  Experience Scale  Salary
# 0  zubair     zeeshan  2/4/2022    323   23  BM           2   MG9  134243

# %%
df[(df["Job"] == "BSM") & (df["Experience"] == 4) | (df["Experience"] == 2)]
# Out:
#      Name Father Name      Date  Marks  Age  Job  Experience Scale  Salary
# 0  zubair     zeeshan  2/4/2022    323   23   BM           2   MG9  134243
# 1    asif      zubair  2/1/2022    434   43  BSM           4  MG10    1234
# 8  Faisal        khan  2/8/2022    223   43  BSM           4   MG9    2335

# %%
df
# Out:
#        Name Father Name      Date  Marks  Age        Job  Experience Scale  \
# 0    zubair     zeeshan  2/4/2022    323   23         BM           2   MG9
# 1      asif      zubair  2/1/2022    434   43        BSM           4  MG10
# 2      khan      faisal  2/2/2022    456   22     Teller           4  MG11
# 3      Khan      noshad  2/3/2022    532   32  Messanger           3  MG12
# 4    shoaib      haider  3/6/2022    155   34        BSM           3  MG11
# 5    Noshad      danish  2/5/2022    663   33      guard           5  MG12
# 6    haider        faiz  2/6/2022    534   44      guard           3  MG12
# 7  khan ali        John  2/7/2022    345   55     Teller           6  MG11
# 8    Faisal        khan  2/8/2022    223   43        BSM           4   MG9
#
#    Salary
# 0  134243
# 1    1234
# 2   27865
# 3   25000
# 4   54788
# 5   19860
# 6   19605
# 7   27474
# 8    2335

# %%
df.sort_values("Salary")
# Out:
#        Name Father Name      Date  Marks  Age        Job  Experience Scale  \
# 1      asif      zubair  2/1/2022    434   43        BSM           4  MG10
# 8    Faisal        khan  2/8/2022    223   43        BSM           4   MG9
# 6    haider        faiz  2/6/2022    534   44      guard           3  MG12
# 5    Noshad      danish  2/5/2022    663   33      guard           5  MG12
# 3      Khan      noshad  2/3/2022    532   32  Messanger           3  MG12
# 7  khan ali        John  2/7/2022    345   55     Teller           6  MG11
# 2      khan      faisal  2/2/2022    456   22     Teller           4  MG11
# 4    shoaib      haider  3/6/2022    155   34        BSM           3  MG11
# 0    zubair     zeeshan  2/4/2022    323   23         BM           2   MG9
#
#    Salary
# 1    1234
# 8    2335
# 6   19605
# 5   19860
# 3   25000
# 7   27474
# 2   27865
# 4   54788
# 0  134243

# %%
df.sort_index()
# Out:
#        Name Father Name      Date  Marks  Age        Job  Experience Scale  \
# 0    zubair     zeeshan  2/4/2022    323   23         BM           2   MG9
# 1      asif      zubair  2/1/2022    434   43        BSM           4  MG10
# 2      khan      faisal  2/2/2022    456   22     Teller           4  MG11
# 3      Khan      noshad  2/3/2022    532   32  Messanger           3  MG12
# 4    shoaib      haider  3/6/2022    155   34        BSM           3  MG11
# 5    Noshad      danish  2/5/2022    663   33      guard           5  MG12
# 6    haider        faiz  2/6/2022    534   44      guard           3  MG12
# 7  khan ali        John  2/7/2022    345   55     Teller           6  MG11
# 8    Faisal        khan  2/8/2022    223   43        BSM           4   MG9
#
#    Salary
# 0  134243
# 1    1234
# 2   27865
# 3   25000
# 4   54788
# 5   19860
# 6   19605
# 7   27474
# 8    2335

# %%
df["Age"].sum()
# Out:
# 329

# %%
df["Experience"].sum()
# Out:
# 34

# %%
df['Age'] = df.Age.astype(int)

# %%
df["Age"].dtype
# Out:
# dtype('int32')

# %%
titanic = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
type(titanic)
# Out:
# pandas.core.frame.DataFrame

# %%
tit = titanic.set_index("PassengerId")

# %%
tit
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
tit["Age"].values
# Out:
# array([22.  , 38.  , 26.  , 35.  , 35.  ,   nan, 54.  ,  2.  , 27.  ,
#        14.  ,  4.  , 58.  , 20.  , 39.  , 14.  , 55.  ,  2.  ,   nan,
#        31.  ,   nan, 35.  , 34.  , 15.  , 28.  ,  8.  , 38.  ,   nan,
#        19.  ,   nan,   nan, 40.  ,   nan,   nan, 66.  , 28.  , 42.  ,
#          nan, 21.  , 18.  , 14.  , 40.  , 27.  ,   nan,  3.  , 19.  ,
#          nan,   nan,   nan,   nan, 18.  ,  7.  , 21.  , 49.  , 29.  ,
#        65.  ,   nan, 21.  , 28.5 ,  5.  , 11.  , 22.  , 38.  , 45.  ,
#         4.  ,   nan,   nan, 29.  , 19.  , 17.  , 26.  , 32.  , 16.  ,
#        21.  , 26.  , 32.  , 25.  ,   nan,   nan,  0.83, 30.  , 22.  ,
#        29.  ,   nan, 28.  , 17.  , 33.  , 16.  ,   nan, 23.  , 24.  ,
#        29.  , 20.  , 46.  , 26.  , 59.  ,   nan, 71.  , 23.  , 34.  ,
#        34.  , 28.  ,   nan, 21.  , 33.  , 37.  , 28.  , 21.  ,   nan,
#        38.  ,   nan, 47.  , 14.5 , 22.  , 20.  , 17.  , 21.  , 70.5 ,
# ...

# %%
tit.keys()
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket',
#        'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
tit
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
tit.rename(columns={"Name":"Name."})
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                          Name.     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
tit.isna().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
tit.isna().sum() / len(tit) * 100
# Out:
# Survived     0.000000
# Pclass       0.000000
# Name         0.000000
# Sex          0.000000
# Age         19.865320
# SibSp        0.000000
# Parch        0.000000
# Ticket       0.000000
# Fare         0.000000
# Cabin       77.104377
# Embarked     0.224467
# dtype: float64

# %%
len(tit.dropna())
# Out:
# 183

# %%
len(df.dropna())
# Out:
# 9

# %%
df.value_counts(dropna=True).sum()
# Out:
# 9

# %%
tit.value_counts(dropna=True).sum()
# Out:
# 183

# %%
tit
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
tit[(tit['Sex'] == "male") & (tit['Survived'] == 1)]
# Out:
#              Survived  Pclass                             Name   Sex   Age  \
# PassengerId
# 18                  1       2     Williams, Mr. Charles Eugene  male   NaN
# 22                  1       2            Beesley, Mr. Lawrence  male  34.0
# 24                  1       1     Sloper, Mr. William Thompson  male  28.0
# 37                  1       3                 Mamee, Mr. Hanna  male   NaN
# 56                  1       1                Woolner, Mr. Hugh  male   NaN
# ...               ...     ...                              ...   ...   ...
# 839                 1       3                  Chip, Mr. Chang  male  32.0
# 840                 1       1             Marechal, Mr. Pierre  male   NaN
# 858                 1       1           Daly, Mr. Peter Denis   male  51.0
# 870                 1       3  Johnson, Master. Harold Theodor  male   4.0
# 890                 1       1            Behr, Mr. Karl Howell  male  26.0
#
# ...

# %%
tit[(tit['Sex'] == "male") & (tit['Survived'] == 1)].sum()
# Out:
# C:\Users\Faaz Ali\AppData\Local\Temp\ipykernel_2544\4030259316.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   tit[(tit['Sex'] == "male") & (tit['Survived'] == 1)].sum()
# Survived                                                  109
# Pclass                                                    220
# Name        Williams, Mr. Charles EugeneBeesley, Mr. Lawre...
# Sex         malemalemalemalemalemalemalemalemalemalemalema...
# Age                                                   2536.67
# SibSp                                                      42
# Parch                                                      39
# Ticket      2443732486981137882677199472661160124873834577...
# Fare                                                4449.5418
# Embarked    SSSCSCSSSCSCSSSSSSSCCSSSSSSSSSSSQSSSSCSSSSSSSS...
# ...

# %%
((tit['Sex'] == "male") & (tit['Survived'] == 1)).sum()
# Out:
# 109

# %%
tit[(tit['Sex'] == "female") & (tit['Survived'] == 1)]
# Out:
#              Survived  Pclass  \
# PassengerId
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 9                   1       3
# 10                  1       2
# ...               ...     ...
# 875                 1       2
# 876                 1       3
# 880                 1       1
# 881                 1       2
# 888                 1       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 10                         Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
# ...                                                        ...     ...   ...
# ...

# %%
tit[(tit['Sex'] == "female") & (tit['Survived'] == 1)].sum()
# Out:
# C:\Users\Faaz Ali\AppData\Local\Temp\ipykernel_2544\3785321823.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   tit[(tit['Sex'] == "female") & (tit['Survived'] == 1)].sum()
# Survived                                                  233
# Pclass                                                    447
# Name        Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex         femalefemalefemalefemalefemalefemalefemalefema...
# Age                                                    5683.0
# SibSp                                                     120
# Parch                                                     120
# Ticket      PC 17599STON/O2. 3101282113803347742237736PP 9...
# Fare                                               12101.6876
# dtype: object

# %%
((tit['Sex'] == "female") & (tit['Survived'] == 1)).sum()
# Out:
# 233

# %%
tit
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
tit.sort_values("Age")[(tit["Age"] == 10) | (tit["Age"] == 30)]
# Out:
# C:\Users\Faaz Ali\AppData\Local\Temp\ipykernel_2544\1974498272.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   tit.sort_values("Age")[(tit["Age"] == 10) | (tit["Age"] == 30)]
#              Survived  Pclass  \
# PassengerId
# 420                 0       3
# 820                 0       3
# 287                 1       3
# 214                 0       2
# 799                 0       3
# 800                 0       3
# 521                 1       1
# 309                 0       2
# 80                  1       3
# 310                 1       1
# 535                 0       3
# 538                 1       1
# 323                 1       2
# 607                 0       3
# 366                 0       3
# 748                 1       2
# 453                 0       1
# 158                 0       3
# 727                 1       2
# 245                 0       3
# 489                 0       3
# 258                 1       1
# 179                 0       2
# ...

# %%
tit.dtypes
# Out:
# Survived      int64
# Pclass        int64
# Name         object
# Sex          object
# Age         float64
# SibSp         int64
# Parch         int64
# Ticket       object
# Fare        float64
# Cabin        object
# Embarked     object
# dtype: object
